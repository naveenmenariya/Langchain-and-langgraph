# %%
# !pip install langgraph langchain google-generativeai
# Out:
# Requirement already satisfied: langgraph in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (1.0.5)
# Requirement already satisfied: langchain in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: google-generativeai in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (0.8.6)
# Requirement already satisfied: langchain-core>=0.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (1.2.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (0.3.1)
# Requirement already satisfied: pydantic>=2.7.4 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (2.45.0)
# Requirement already satisfied: protobuf in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: tqdm in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (0.12.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.1)
# Requirement already satisfied: anyio in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.0)
# Requirement already satisfied: certifi in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/naveen/Desktop/langchain/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.6.2)

# %%
from typing import TypedDict

class PortfolioState(TypedDict):
    amount_usd: float
    total_usd: float
    total_inr: float

# %%
def calc_total(state: PortfolioState) -> PortfolioState:
    state['total_usd'] = state['amount_usd'] * 1.08
    return state

def convert_to_inr(state: PortfolioState) -> PortfolioState:
    state['total_inr'] = state['total_usd'] * 85
    return state

# %%
from langgraph.graph import StateGraph, START, END

builder = StateGraph(PortfolioState)

builder.add_node("calc_total_node", calc_total)
builder.add_node("convert_to_inr_node", convert_to_inr)

builder.add_edge(START, "calc_total_node")
builder.add_edge("calc_total_node", "convert_to_inr_node")
builder.add_edge("convert_to_inr_node", END)

graph = builder.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
graph.invoke({"amount_usd": 100000})
# Out:
# {'amount_usd': 100000, 'total_usd': 108000.0, 'total_inr': 9180000.0}
